# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12,6)

# %% [markdown]
# # Predicting Phishing Web Page Using Machine Learning
#
# Phishing is a method of trying to gather personal information using deceptive e-mails and websites.
#
# In this notebook, we will read the data and look at what are the features that can give us information on what are the attributes of a phishing website

# %% [markdown]
# # Loading the data
#
# We will start by loading the provided csv data using pandas read_csv method

# %%
data = pd.read_csv("D:\PROJECTS\Dataset\Phishing_Legitimate_full.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\rahil\AppData\Local\Temp\ipykernel_14692\2859278723.py:1: SyntaxWarning: invalid escape sequence '\P'
#   data = pd.read_csv("D:\PROJECTS\Dataset\Phishing_Legitimate_full.csv")

# %% [markdown]
# # Convert data
#
# In this phase we will convert float64 and int64 data to type 32, by doing this we can save the memory usage and we can prepare the data for using with CuML later for training purpose
#
# As we can see the data has 10k rows and 50 columns including labels

# %%
float_cols = data.select_dtypes('float64').columns
for c in float_cols:
    data[c] = data[c].astype('float32')
    
int_cols = data.select_dtypes('int64').columns
for c in int_cols:
    data[c] = data[c].astype('int32')
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  49  CLASS_LABEL                         10000 non-null  int32
# dtypes: float32(3), int32(47)
# memory usage: 1.9 MB

# %%
data.rename(columns={'CLASS_LABEL': 'labels'}, inplace=True)

# %% [markdown]
# # View the data
#
# Lets look at random 5 rows from the dataset, it seems like we have mix of ranged data, some column have smaller range compared to others

# %%
data.sample(5)
# Out:
#         id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 9379  9380        2               1          2         51        2
# 3861  3862        2               1          0         38        1
# 2225  2226        2               0          3        202        3
# 4722  4723        3               1          1         42        0
# 3581  3582        3               1         12        155        1
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  NumPercent  \
# 9379                  0         0            0              0           0
# 3861                  1         0            0              0           0
# 2225                  0         0            0              6           0
# 4722                  0         0            0              0           0
# 3581                  0         0            0              1           0
#
#       NumQueryComponents  NumAmpersand  NumHash  NumNumericChars  NoHttps  \
# 9379                   0             0        0                7        1
# 3861                   0             0        0                2        1
# 2225                   6             5        0                5        1
# 4722                   0             0        0                1        1
# 3581                   0             0        0               48        1
#
#       RandomString  IpAddress  DomainInSubdomains  DomainInPaths  \
# 9379             1          0                   0              0
# 3861             1          0                   0              0
# 2225             0          0                   0              1
# 4722             0          0                   0              0
# 3581             1          0                   0              1
#
#       HttpsInHostname  HostnameLength  PathLength  QueryLength  \
# 9379                0              19          25            0
# 3861                0              30           1            0
# 2225                0              14          34          146
# 4722                0              23          12            0
# 3581                0              17         131            0
#
#       DoubleSlashInPath  NumSensitiveWords  EmbeddedBrandName  \
# 9379                  0                  0                  0
# 3861                  0                  0                  0
# 2225                  0                  1                  0
# 4722                  0                  0                  0
# 3581                  0                  1                  0
#
#       PctExtHyperlinks  PctExtResourceUrls  ExtFavicon  InsecureForms  \
# 9379          0.149254            0.315789           0              1
# 3861          0.000000            0.250000           1              1
# 2225          0.040541            0.178571           0              1
# 4722          1.000000            1.000000           1              1
# 3581          0.066667            0.125000           1              1
#
#       RelativeFormAction  ExtFormAction  AbnormalFormAction  \
# 9379                   0              0                   0
# 3861                   0              0                   0
# 2225                   0              1                   0
# 4722                   0              1                   0
# 3581                   1              0                   1
#
#       PctNullSelfRedirectHyperlinks  FrequentDomainNameMismatch  \
# 9379                       0.074627                           0
# 3861                       0.882353                           0
# 2225                       0.000000                           0
# 4722                       0.000000                           1
# 3581                       0.000000                           0
#
#       FakeLinkInStatusBar  RightClickDisabled  PopUpWindow  SubmitInfoToEmail  \
# 9379                    0                   0            0                  0
# 3861                    0                   0            0                  0
# 2225                    0                   0            0                  0
# 4722                    0                   0            0                  0
# 3581                    0                   0            0                  0
#
#       IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 9379              1             0                 0                 1
# 3861              0             0                 0                 1
# 2225              0             0                 0                 1
# 4722              0             0                 0                 1
# 3581              1             0                 0                 1
#
#       UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 9379            1                     0                       1
# 3861            1                     1                       1
# 2225           -1                     1                       0
# 4722            1                    -1                       0
# 3581           -1                     1                      -1
#
#       ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  labels
# 9379                    0                                   1       0
# 3861                    0                                  -1       1
# 2225                    0                                   1       1
# 4722                   -1                                  -1       1
# 3581                    0                                   1       1

# %% [markdown]
# # Summary Statistics
#
# By using the describe method, we can see some of the columns have high variance and some have smaller variance, this is due to the fact that some of the column have bigger values and bigger ranges

# %%
data.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      0.000000      0.000000
# 50%        0.000000           0.000000      0.000000      0.000000
# 75%        2.000000           0.000000      0.000000      0.000000
# max       55.000000           9.000000      1.000000      1.000000
#
#        NumUnderscore    NumPercent  NumQueryComponents  NumAmpersand  \
# count    10000.00000  10000.000000        10000.000000  10000.000000
# mean         0.32320      0.073800            0.458600      0.277200
# std          1.11466      0.622248            1.344793      1.117356
# min          0.00000      0.000000            0.000000      0.000000
# 25%          0.00000      0.000000            0.000000      0.000000
# 50%          0.00000      0.000000            0.000000      0.000000
# 75%          0.00000      0.000000            0.000000      0.000000
# max         18.00000     19.000000           23.000000     22.000000
#
#             NumHash  NumNumericChars       NoHttps  RandomString  \
# count  10000.000000     10000.000000  10000.000000   10000.00000
# mean       0.002300         5.810300      0.988800       0.52520
# std        0.047906         9.617877      0.105241       0.49939
# min        0.000000         0.000000      0.000000       0.00000
# 25%        0.000000         0.000000      1.000000       0.00000
# 50%        0.000000         2.000000      1.000000       1.00000
# 75%        0.000000         8.000000      1.000000       1.00000
# max        1.000000       111.000000      1.000000       1.00000
#
#           IpAddress  DomainInSubdomains  DomainInPaths  HttpsInHostname  \
# count  10000.000000        10000.000000   10000.000000          10000.0
# mean       0.017200            0.022200       0.428900              0.0
# std        0.130023            0.147341       0.494944              0.0
# min        0.000000            0.000000       0.000000              0.0
# 25%        0.000000            0.000000       0.000000              0.0
# 50%        0.000000            0.000000       0.000000              0.0
# 75%        0.000000            0.000000       1.000000              0.0
# max        1.000000            1.000000       1.000000              0.0
#
#        HostnameLength    PathLength   QueryLength  DoubleSlashInPath  \
# count     10000.00000  10000.000000  10000.000000       10000.000000
# mean         18.82430     35.564900      8.606500           0.000900
# std           8.11654     24.588502     24.313053           0.029988
# min           4.00000      0.000000      0.000000           0.000000
# 25%          14.00000     18.000000      0.000000           0.000000
# 50%          18.00000     30.000000      0.000000           0.000000
# 75%          22.00000     48.000000      0.000000           0.000000
# max         137.00000    161.000000    188.000000           1.000000
#
#        NumSensitiveWords  EmbeddedBrandName  PctExtHyperlinks  \
# count       10000.000000       10000.000000      10000.000000
# mean            0.109300           0.057100          0.241334
# std             0.368737           0.232045          0.342370
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.071429
# 75%             0.000000           0.000000          0.315874
# max             3.000000           1.000000          1.000000
#
#        PctExtResourceUrls    ExtFavicon  InsecureForms  RelativeFormAction  \
# count        10000.000000  10000.000000   10000.000000        10000.000000
# mean             0.392932      0.167200       0.844000            0.248700
# std              0.387292      0.373173       0.362873            0.432281
# min              0.000000      0.000000       0.000000            0.000000
# 25%              0.030303      0.000000       1.000000            0.000000
# 50%              0.247511      0.000000       1.000000            0.000000
# 75%              0.785714      0.000000       1.000000            0.000000
# max              1.000000      1.000000       1.000000            1.000000
#
#        ExtFormAction  AbnormalFormAction  PctNullSelfRedirectHyperlinks  \
# count     10000.0000        10000.000000                   10000.000000
# mean          0.1018            0.057600                       0.136136
# std           0.3024            0.232997                       0.312413
# min           0.0000            0.000000                       0.000000
# 25%           0.0000            0.000000                       0.000000
# 50%           0.0000            0.000000                       0.000000
# 75%           0.0000            0.000000                       0.047619
# max           1.0000            1.000000                       1.000000
#
#        FrequentDomainNameMismatch  FakeLinkInStatusBar  RightClickDisabled  \
# count                10000.000000         10000.000000        10000.000000
# mean                     0.215300             0.005500            0.014000
# std                      0.411051             0.073961            0.117496
# min                      0.000000             0.000000            0.000000
# 25%                      0.000000             0.000000            0.000000
# 50%                      0.000000             0.000000            0.000000
# 75%                      0.000000             0.000000            0.000000
# max                      1.000000             1.000000            1.000000
#
#         PopUpWindow  SubmitInfoToEmail  IframeOrFrame  MissingTitle  \
# count  10000.000000       10000.000000   10000.000000   10000.00000
# mean       0.004900           0.128800       0.339600       0.03220
# std        0.069832           0.334995       0.473597       0.17654
# min        0.000000           0.000000       0.000000       0.00000
# 25%        0.000000           0.000000       0.000000       0.00000
# 50%        0.000000           0.000000       0.000000       0.00000
# 75%        0.000000           0.000000       1.000000       0.00000
# max        1.000000           1.000000       1.000000       1.00000
#
#        ImagesOnlyInForm  SubdomainLevelRT   UrlLengthRT  PctExtResourceUrlsRT  \
# count      10000.000000      10000.000000  10000.000000          10000.000000
# mean           0.030400          0.956600      0.020200              0.353300
# std            0.171694          0.248037      0.820036              0.888908
# min            0.000000         -1.000000     -1.000000             -1.000000
# 25%            0.000000          1.000000     -1.000000             -1.000000
# 50%            0.000000          1.000000      0.000000              1.000000
# 75%            0.000000          1.000000      1.000000              1.000000
# max            1.000000          1.000000      1.000000              1.000000
#
#        AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# count            10000.000000         10000.000000
# mean                 0.793200             0.173400
# std                  0.521019             0.755771
# min                 -1.000000            -1.000000
# 25%                  1.000000             0.000000
# 50%                  1.000000             0.000000
# 75%                  1.000000             1.000000
# max                  1.000000             1.000000
#
#        PctExtNullSelfRedirectHyperlinksRT        labels
# count                        10000.000000  10000.000000
# mean                             0.314100      0.500000
# std                              0.897843      0.500025
# min                             -1.000000      0.000000
# 25%                             -1.000000      0.000000
# 50%                              1.000000      0.500000
# 75%                              1.000000      1.000000
# max                              1.000000      1.000000

# %% [markdown]
# # Balance/Imbalanced Data
#
# The data is balanced for non-phising and phising label

# %%
data['labels'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='labels'>

# %% [markdown]
# # Spearman Correlation
#
# By looking the spearman correlation, we can find which features are linearly correlated in terms of predicting if a site is phising or not

# %%
def corr_heatmap(data, idx_s, idx_e):
    y = data['labels']
    temp = data.iloc[:, idx_s:idx_e]
    if 'id' in temp.columns:
        del temp['id']
    temp['labels'] = y
    sns.heatmap(temp.corr(), annot=True, fmt='.2f')
    plt.show()

# %% [markdown]
# # First 10 columns
#
# By looking at the first 10 columns against labels, we can concluded that non of the features have strong correlation with the labels, however, NumDash has some significant negative effect towards the labels, which could mean if there is less number of dash then it is more likely to be phising site

# %%
corr_heatmap(data, 0, 10)

# %% [markdown]
# # Columns 10 to 20
#
# There are no strong or even medium level strength correlation features with labels

# %%
corr_heatmap(data, 10, 20)

# %% [markdown]
# # Columns 20 to 30
#
# Still no strong correlation feature

# %%
corr_heatmap(data, 20, 30)

# %% [markdown]
# # Columns 30 to 40
#
# Well here we have a few features that are linearly correlated to our dep variable
#
# * InsecureForms shows that as the value is higher so the probability of being a phising site
# * PctNullSelfRedirectHyperlinks shows the same positive correlation as InsecureForms
# * FequentDomainNameMismatch shows that it has medium linear correlation in positive direction
# * SubmitInfoToEmail seems to indicate that sites that ask users to submit their details to emails seems to be more high probability for phising

# %%
corr_heatmap(data, 30, 40)

# %% [markdown]
# # Columsn 40 to 50
#
# The only column in this group that has some correlation with labels is PctExtNullSelfRedirectHyperlinksRT and it has negative effect towards labels which could mean that when the number of percent of null self redirect hyperlinks occur hence the probabiliy of phising increases

# %%
corr_heatmap(data, 40, 50)

# %% [markdown]
# # Mutual Info
#
# We will use mutual info classifier to find non linear and linear correlation betweem the features and labels

# %%
from sklearn.feature_selection import mutual_info_classif
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from sklearn.feature_selection import mutual_info_classif
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
X = data.drop(['id', 'labels'], axis=1)
y = data['labels']

# %%
discrete_features = X.dtypes == int

# %% [markdown]
# Here we process the scores and we can see that now mutual info is showing a bit different list from spearman corr

# %%
mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
mi_scores = pd.Series(mi_scores, name='MI Scores', index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
# Out:
# PctExtHyperlinks                      0.466468
# PctExtResourceUrls                    0.287948
# PctNullSelfRedirectHyperlinks         0.224680
# PctExtNullSelfRedirectHyperlinksRT    0.218247
# NumNumericChars                       0.131774
# FrequentDomainNameMismatch            0.124296
# ExtMetaScriptLinkRT                   0.121077
# NumDash                               0.110516
# SubmitInfoToEmail                     0.080530
# NumDots                               0.062004
# PathLength                            0.058226
# InsecureForms                         0.051746
# PathLevel                             0.050815
# QueryLength                           0.047440
# NumSensitiveWords                     0.042470
# UrlLength                             0.040701
# IframeOrFrame                         0.027984
# PctExtResourceUrlsRT                  0.025875
# NumQueryComponents                    0.024486
# UrlLengthRT                           0.022790
# HostnameLength                        0.017741
# AbnormalExtFormActionR                0.016700
# NumAmpersand                          0.016023
# MissingTitle                          0.015247
# AbnormalFormAction                    0.014123
# IpAddress                             0.012209
# NumDashInHostname                     0.012159
# TildeSymbol                           0.011472
# DomainInSubdomains                    0.010164
# NumUnderscore                         0.008946
# EmbeddedBrandName                     0.008654
# RightClickDisabled                    0.006752
# DomainInPaths                         0.004976
# PopUpWindow                           0.004869
# RandomString                          0.003691
# NumPercent                            0.003005
# AtSymbol                              0.002353
# NoHttps                               0.002220
# SubdomainLevel                        0.001773
# RelativeFormAction                    0.000577
# DoubleSlashInPath                     0.000343
# FakeLinkInStatusBar                   0.000000
# ExtFavicon                            0.000000
# ImagesOnlyInForm                      0.000000
# SubdomainLevelRT                      0.000000
# HttpsInHostname                       0.000000
# NumHash                               0.000000
# ExtFormAction                         0.000000
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("MI Scores")
    
plt.figure(dpi=100, figsize=(12,12))
plot_mi_scores(mi_scores)

# %% [markdown]
# # Prediction
#
# We will first use logistic regression as for baseline, then try to beat the baseline using random forest classifer
#
# Our evaluation metrics will be accuracy, precision, recall and f1 score
#
# Below we import all the required modules

# %%
from sklearn.linear_model import LogisticRegression
#from cuml.ensemble import RandomForestClassifier as cuRfc
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# # Train logistic models
#
# This method is to perform a repetative training process using logistic regression model, the purpose for this is to find the optimal number of features that can be used to find the best fitted model without adjusting much of the hyperparameters, hence the idea here is to go with Data-Centric training, basically the method takes number of top N features to be used for training the model and all the evaluation metrics are returned for evaluation purpose

# %%
def train_logistic(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    lr = LogisticRegression(max_iter=10000)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %% [markdown]
# Here the loop will be starting from 20 as we will start training with top 20 features up to all 50 features to find optimal number of features needed for this problem

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_logistic(data, i)
    print("Performance for Logistic Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for Logistic Model with Top 20 features is precision : 0.9185929648241206, recall : 0.9326530612244898, f1 score : 0.9255696202531645, accuracy : 0.9265
# Performance for Logistic Model with Top 21 features is precision : 0.9161676646706587, recall : 0.9415384615384615, f1 score : 0.9286798179059179, accuracy : 0.9295
# Performance for Logistic Model with Top 22 features is precision : 0.9107662463627546, recall : 0.9523326572008114, f1 score : 0.9310857709469509, accuracy : 0.9305
# Performance for Logistic Model with Top 23 features is precision : 0.9151219512195122, recall : 0.9465186680121089, f1 score : 0.9305555555555556, accuracy : 0.93
# Performance for Logistic Model with Top 24 features is precision : 0.91991991991992, recall : 0.9226907630522089, f1 score : 0.9213032581453635, accuracy : 0.9215
# Performance for Logistic Model with Top 25 features is precision : 0.9275653923541247, recall : 0.9350912778904665, f1 score : 0.9313131313131313, accuracy : 0.932
# Performance for Logistic Model with Top 26 features is precision : 0.9326732673267327, recall : 0.9280788177339901, f1 score : 0.9303703703703704, accuracy : 0.9295
# Performance for Logistic Model with Top 27 features is precision : 0.9317307692307693, recall : 0.930835734870317, f1 score : 0.9312830370014415, accuracy : 0.9285
# Performance for Logistic Model with Top 28 features is precision : 0.9032901296111665, recall : 0.934984520123839, f1 score : 0.9188640973630832, accuracy : 0.92
# Performance for Logistic Model with Top 29 features is precision : 0.9148296593186372, recall : 0.9325842696629213, f1 score : 0.9236216489630753, accuracy : 0.9245
# Performance for Logistic Model with Top 30 features is precision : 0.9304435483870968, recall : 0.9342105263157895, f1 score : 0.9323232323232322, accuracy : 0.933
# Performance for Logistic Model with Top 31 features is precision : 0.930161943319838, recall : 0.9425641025641026, f1 score : 0.9363219561895058, accuracy : 0.9375
# Performance for Logistic Model with Top 32 features is precision : 0.9313824419778002, recall : 0.9351570415400202, f1 score : 0.9332659251769464, accuracy : 0.934
# Performance for Logistic Model with Top 33 features is precision : 0.9311348205625606, recall : 0.940254652301665, f1 score : 0.935672514619883, accuracy : 0.934
# Performance for Logistic Model with Top 34 features is precision : 0.9276381909547738, recall : 0.9408766564729868, f1 score : 0.9342105263157895, accuracy : 0.935
# Performance for Logistic Model with Top 35 features is precision : 0.9314516129032258, recall : 0.9361702127659575, f1 score : 0.9338049519959575, accuracy : 0.9345
# Performance for Logistic Model with Top 36 features is precision : 0.9177949709864603, recall : 0.9509018036072144, f1 score : 0.9340551181102362, accuracy : 0.933
# Performance for Logistic Model with Top 37 features is precision : 0.9168316831683169, recall : 0.9362992922143579, f1 score : 0.926463231615808, accuracy : 0.9265
# Performance for Logistic Model with Top 38 features is precision : 0.9278152069297402, recall : 0.9460255152109912, f1 score : 0.9368318756073858, accuracy : 0.935
# Performance for Logistic Model with Top 39 features is precision : 0.9383561643835616, recall : 0.9429695181907571, f1 score : 0.9406571848945562, accuracy : 0.9395
# Performance for Logistic Model with Top 40 features is precision : 0.9265873015873016, recall : 0.9405840886203424, f1 score : 0.9335332333833084, accuracy : 0.9335
# Performance for Logistic Model with Top 41 features is precision : 0.9373191899710704, recall : 0.9510763209393346, f1 score : 0.9441476444876152, accuracy : 0.9425
# Performance for Logistic Model with Top 42 features is precision : 0.9217221135029354, recall : 0.9457831325301205, f1 score : 0.933597621407334, accuracy : 0.933
# Performance for Logistic Model with Top 43 features is precision : 0.9393326592517695, recall : 0.9528205128205128, f1 score : 0.9460285132382892, accuracy : 0.947
# Performance for Logistic Model with Top 44 features is precision : 0.9344262295081968, recall : 0.9661016949152542, f1 score : 0.95, accuracy : 0.949
# Performance for Logistic Model with Top 45 features is precision : 0.945, recall : 0.9526209677419355, f1 score : 0.9487951807228916, accuracy : 0.949
# Performance for Logistic Model with Top 46 features is precision : 0.9415204678362573, recall : 0.9573835480673935, f1 score : 0.9493857493857494, accuracy : 0.9485
# Performance for Logistic Model with Top 47 features is precision : 0.9282868525896414, recall : 0.9578622816032888, f1 score : 0.9428426909458776, accuracy : 0.9435
# Performance for Logistic Model with Top 48 features is precision : 0.9297725024727992, recall : 0.9485368314833501, f1 score : 0.9390609390609391, accuracy : 0.939
# Performance for Logistic Model with Top 49 features is precision : 0.9281314168377823, recall : 0.9406867845993756, f1 score : 0.9343669250645994, accuracy : 0.9365
# Performance for Logistic Model with Top 50 features is precision : 0.9404170804369414, recall : 0.9594731509625126, f1 score : 0.9498495486459378, accuracy : 0.95

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.918593  0.932653  0.925570    0.9265
# 1                21   0.916168  0.941538  0.928680    0.9295
# 2                22   0.910766  0.952333  0.931086    0.9305
# 3                23   0.915122  0.946519  0.930556    0.9300
# 4                24   0.919920  0.922691  0.921303    0.9215
# 5                25   0.927565  0.935091  0.931313    0.9320
# 6                26   0.932673  0.928079  0.930370    0.9295
# 7                27   0.931731  0.930836  0.931283    0.9285
# 8                28   0.903290  0.934985  0.918864    0.9200
# 9                29   0.914830  0.932584  0.923622    0.9245
# 10               30   0.930444  0.934211  0.932323    0.9330
# 11               31   0.930162  0.942564  0.936322    0.9375
# 12               32   0.931382  0.935157  0.933266    0.9340
# 13               33   0.931135  0.940255  0.935673    0.9340
# 14               34   0.927638  0.940877  0.934211    0.9350
# 15               35   0.931452  0.936170  0.933805    0.9345
# 16               36   0.917795  0.950902  0.934055    0.9330
# 17               37   0.916832  0.936299  0.926463    0.9265
# 18               38   0.927815  0.946026  0.936832    0.9350
# 19               39   0.938356  0.942970  0.940657    0.9395
# 20               40   0.926587  0.940584  0.933533    0.9335
# 21               41   0.937319  0.951076  0.944148    0.9425
# 22               42   0.921722  0.945783  0.933598    0.9330
# 23               43   0.939333  0.952821  0.946029    0.9470
# 24               44   0.934426  0.966102  0.950000    0.9490
# 25               45   0.945000  0.952621  0.948795    0.9490
# 26               46   0.941520  0.957384  0.949386    0.9485
# 27               47   0.928287  0.957862  0.942843    0.9435
# 28               48   0.929773  0.948537  0.939061    0.9390
# 29               49   0.928131  0.940687  0.934367    0.9365
# 30               50   0.940417  0.959473  0.949850    0.9500

# %% [markdown]
# # Visualize Logistic Reg Performance
#
# As we can see, the model had ups and downs during the training as more number of features were added, as our target is to maximize all the metrics we have to find the number of features that gives us the best of all metrics, from the figure below, we can see that recall is constantly performing good but our model tend to have problem with precision score, hence to choose the best N of features, we have to pick the area where all the metrics are performing and based on the figure I would say its around 39 features

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %% [markdown]
# # Training Cattboost Classifier on GPU
#
# It is the same method as logistic reg, the only diff is that we are now using random forest classifier for training and trying to beat the logistic baseline

# %%
from catboost import CatBoostClassifier

# %%
def train_clf(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    

    clf = CatBoostClassifier(iterations=200,learning_rate=0.1)
    
    clf.fit(X_train, y_train,verbose=False)

    
    y_pred = clf.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_clf(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for clf Model with Top 20 features is precision : 0.9806320081549439, recall : 0.9876796714579056, f1 score : 0.9841432225063939, accuracy : 0.9845
# Performance for clf Model with Top 21 features is precision : 0.9761904761904762, recall : 0.9915878023133544, f1 score : 0.983828899321857, accuracy : 0.9845
# Performance for clf Model with Top 22 features is precision : 0.9869739478957916, recall : 0.9879638916750251, f1 score : 0.987468671679198, accuracy : 0.9875
# Performance for clf Model with Top 23 features is precision : 0.9805327868852459, recall : 0.9825462012320328, f1 score : 0.9815384615384616, accuracy : 0.982
# Performance for clf Model with Top 24 features is precision : 0.9823874755381604, recall : 0.9833496571988247, f1 score : 0.9828683308859519, accuracy : 0.9825
# Performance for clf Model with Top 25 features is precision : 0.9889558232931727, recall : 0.9830339321357285, f1 score : 0.985985985985986, accuracy : 0.986
# Performance for clf Model with Top 26 features is precision : 0.9795918367346939, recall : 0.9748549323017408, f1 score : 0.9772176442074648, accuracy : 0.9765
# Performance for clf Model with Top 27 features is precision : 0.9783950617283951, recall : 0.9865145228215768, f1 score : 0.9824380165289256, accuracy : 0.983
# Performance for clf Model with Top 28 features is precision : 0.981335952848723, recall : 0.9861796643632774, f1 score : 0.9837518463810931, accuracy : 0.9835
# Performance for clf Model with Top 29 features is precision : 0.9849548645937813, recall : 0.9859437751004017, f1 score : 0.9854490717511291, accuracy : 0.9855
# Performance for clf Model with Top 30 features is precision : 0.9739217652958877, recall : 0.9788306451612904, f1 score : 0.9763700351935646, accuracy : 0.9765
# Performance for clf Model with Top 31 features is precision : 0.9898477157360406, recall : 0.9858442871587462, f1 score : 0.9878419452887538, accuracy : 0.988
# Performance for clf Model with Top 32 features is precision : 0.9823182711198428, recall : 0.9852216748768473, f1 score : 0.983767830791933, accuracy : 0.9835
# Performance for clf Model with Top 33 features is precision : 0.9806763285024155, recall : 0.9873540856031129, f1 score : 0.9840038778477945, accuracy : 0.9835
# Performance for clf Model with Top 34 features is precision : 0.9840478564307079, recall : 0.9889779559118237, f1 score : 0.9865067466266867, accuracy : 0.9865
# Performance for clf Model with Top 35 features is precision : 0.9803729146221786, recall : 0.9881305637982196, f1 score : 0.9842364532019705, accuracy : 0.984
# Performance for clf Model with Top 36 features is precision : 0.9761668321747765, recall : 0.9859578736208626, f1 score : 0.9810379241516965, accuracy : 0.981
# Performance for clf Model with Top 37 features is precision : 0.9767206477732794, recall : 0.9877175025588536, f1 score : 0.9821882951653944, accuracy : 0.9825
# Performance for clf Model with Top 38 features is precision : 0.9882121807465619, recall : 0.9901574803149606, f1 score : 0.9891838741396263, accuracy : 0.989
# Performance for clf Model with Top 39 features is precision : 0.9769307923771314, recall : 0.9878296146044625, f1 score : 0.9823499747856783, accuracy : 0.9825
# Performance for clf Model with Top 40 features is precision : 0.9828801611278952, recall : 0.9809045226130654, f1 score : 0.9818913480885312, accuracy : 0.982
# Performance for clf Model with Top 41 features is precision : 0.9799196787148594, recall : 0.9838709677419355, f1 score : 0.9818913480885312, accuracy : 0.982
# Performance for clf Model with Top 42 features is precision : 0.9846301633045149, recall : 0.9855769230769231, f1 score : 0.9851033157135993, accuracy : 0.9845
# Performance for clf Model with Top 43 features is precision : 0.98046875, recall : 0.9872173058013766, f1 score : 0.9838314551690349, accuracy : 0.9835
# Performance for clf Model with Top 44 features is precision : 0.9828109201213346, recall : 0.9828109201213346, f1 score : 0.9828109201213346, accuracy : 0.983
# Performance for clf Model with Top 45 features is precision : 0.983201581027668, recall : 0.9880834160873883, f1 score : 0.9856364536899456, accuracy : 0.9855
# Performance for clf Model with Top 46 features is precision : 0.9899091826437941, recall : 0.9819819819819819, f1 score : 0.9859296482412061, accuracy : 0.986
# Performance for clf Model with Top 47 features is precision : 0.9859437751004017, recall : 0.9869346733668342, f1 score : 0.9864389753892516, accuracy : 0.9865
# Performance for clf Model with Top 48 features is precision : 0.9827235772357723, recall : 0.986734693877551, f1 score : 0.984725050916497, accuracy : 0.985
# Performance for clf Model with Top 49 features is precision : 0.9771598808341608, recall : 0.9869608826479438, f1 score : 0.9820359281437125, accuracy : 0.982
# Performance for clf Model with Top 50 features is precision : 0.9807692307692307, recall : 0.9807692307692307, f1 score : 0.9807692307692307, accuracy : 0.981

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.980632  0.987680  0.984143    0.9845
# 1                21   0.976190  0.991588  0.983829    0.9845
# 2                22   0.986974  0.987964  0.987469    0.9875
# 3                23   0.980533  0.982546  0.981538    0.9820
# 4                24   0.982387  0.983350  0.982868    0.9825
# 5                25   0.988956  0.983034  0.985986    0.9860
# 6                26   0.979592  0.974855  0.977218    0.9765
# 7                27   0.978395  0.986515  0.982438    0.9830
# 8                28   0.981336  0.986180  0.983752    0.9835
# 9                29   0.984955  0.985944  0.985449    0.9855
# 10               30   0.973922  0.978831  0.976370    0.9765
# 11               31   0.989848  0.985844  0.987842    0.9880
# 12               32   0.982318  0.985222  0.983768    0.9835
# 13               33   0.980676  0.987354  0.984004    0.9835
# 14               34   0.984048  0.988978  0.986507    0.9865
# 15               35   0.980373  0.988131  0.984236    0.9840
# 16               36   0.976167  0.985958  0.981038    0.9810
# 17               37   0.976721  0.987718  0.982188    0.9825
# 18               38   0.988212  0.990157  0.989184    0.9890
# 19               39   0.976931  0.987830  0.982350    0.9825
# 20               40   0.982880  0.980905  0.981891    0.9820
# 21               41   0.979920  0.983871  0.981891    0.9820
# 22               42   0.984630  0.985577  0.985103    0.9845
# 23               43   0.980469  0.987217  0.983831    0.9835
# 24               44   0.982811  0.982811  0.982811    0.9830
# 25               45   0.983202  0.988083  0.985636    0.9855
# 26               46   0.989909  0.981982  0.985930    0.9860
# 27               47   0.985944  0.986935  0.986439    0.9865
# 28               48   0.982724  0.986735  0.984725    0.9850
# 29               49   0.977160  0.986961  0.982036    0.9820
# 30               50   0.980769  0.980769  0.980769    0.9810

# %% [markdown]
# # Visualize CatBoostClassifier Performance
#
# Our goal is to beat logistic regression baseline which is
#
# * accuracy = 0.947162
# * precision = 0.957468
# * recall = 0.952287
# * f1_score = 0.9515
#
# So by visualizing the figure below, we can conclude that the best number of features for this model would be 32, one less than logistic regression, the reason why I chose 32 is because that is the number of features that allowed the model to perform the best across all the evaluation metric

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='Precision Score')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <AxesSubplot:xlabel='num_of_features', ylabel='precision'>

# %% [markdown]
# # Final CatBoostClassifier Model
#
# Lets train the final CatBoostClassifier based on the optimal N number of features

# %%
top_n_features = mi_scores.sort_values(ascending=False).head(51).index.tolist()
X = data[top_n_features]
y = data['labels']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

clf = CatBoostClassifier(loss_function='Logloss',
                         verbose = False,
                        eval_metric='AUC',
                        iterations=500,
                         thread_count = None,
                        random_state=1)
    
clf.fit(X_train, y_train,verbose=False)


y_pred = clf.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("Performance for RFC Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(27, precision, recall, f1, accuracy))
# Out:
# Performance for RFC Model with Top 27 features is precision : 0.9817444219066938, recall : 0.9877551020408163, f1 score : 0.9847405900305187, accuracy : 0.985

# %% [markdown]
# # Performance
#
# The model is now capable of predicting at up to 98% accuracy and also precision and recall, this shows the model has high confidence in predicting phishing or non-phishing site

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1020
#            1       0.98      0.99      0.98       980
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.99      0.98      2000
# weighted avg       0.99      0.98      0.99      2000

# %%
# importing modules
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# <a href="https://techfor-today.com/sklearn-confusion-matrix-in-machine-learning/">confusion matrix</a> plotting
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
# labelling
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.show()

# %%
from lightgbm import LGBMClassifier
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def train_LGBM(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    

    LGBM = LGBMClassifier()
    
    LGBM.fit(X_train, y_train)

    
    y_pred = LGBM.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_LGBM(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for clf Model with Top 20 features is precision : 0.9876543209876543, recall : 0.9825997952917093, f1 score : 0.9851205746536684, accuracy : 0.9855
# Performance for clf Model with Top 21 features is precision : 0.9820359281437125, recall : 0.9771598808341608, f1 score : 0.9795918367346937, accuracy : 0.9795
# Performance for clf Model with Top 22 features is precision : 0.9840478564307079, recall : 0.987, f1 score : 0.9855217174238642, accuracy : 0.9855
# Performance for clf Model with Top 23 features is precision : 0.9880239520958084, recall : 0.99, f1 score : 0.989010989010989, accuracy : 0.989
# Performance for clf Model with Top 24 features is precision : 0.972, recall : 0.9808274470232089, f1 score : 0.9763937719738826, accuracy : 0.9765
# Performance for clf Model with Top 25 features is precision : 0.9792694965449161, recall : 0.9890329012961117, f1 score : 0.9841269841269842, accuracy : 0.984
# Performance for clf Model with Top 26 features is precision : 0.9804727646454265, recall : 0.9804727646454265, f1 score : 0.9804727646454265, accuracy : 0.981
# Performance for clf Model with Top 27 features is precision : 0.9839518555667001, recall : 0.9819819819819819, f1 score : 0.9829659318637274, accuracy : 0.983
# Performance for clf Model with Top 28 features is precision : 0.9821251241310824, recall : 0.9801783944499505, f1 score : 0.9811507936507936, accuracy : 0.981
# Performance for clf Model with Top 29 features is precision : 0.9822485207100592, recall : 0.9900596421471173, f1 score : 0.986138613861386, accuracy : 0.986
# Performance for clf Model with Top 30 features is precision : 0.9811881188118812, recall : 0.9850894632206759, f1 score : 0.9831349206349207, accuracy : 0.983
# Performance for clf Model with Top 31 features is precision : 0.9805068226120858, recall : 0.9862745098039216, f1 score : 0.9833822091886608, accuracy : 0.983
# Performance for clf Model with Top 32 features is precision : 0.987, recall : 0.9791666666666666, f1 score : 0.9830677290836654, accuracy : 0.983
# Performance for clf Model with Top 33 features is precision : 0.98043254376931, recall : 0.9834710743801653, f1 score : 0.9819494584837546, accuracy : 0.9825
# Performance for clf Model with Top 34 features is precision : 0.9801587301587301, recall : 0.988, f1 score : 0.9840637450199202, accuracy : 0.984
# Performance for clf Model with Top 35 features is precision : 0.9883381924198251, recall : 0.9845111326234269, f1 score : 0.9864209505334627, accuracy : 0.986
# Performance for clf Model with Top 36 features is precision : 0.9881539980256664, recall : 0.980411361410382, f1 score : 0.984267453294002, accuracy : 0.984
# Performance for clf Model with Top 37 features is precision : 0.985014985014985, recall : 0.981094527363184, f1 score : 0.983050847457627, accuracy : 0.983
# Performance for clf Model with Top 38 features is precision : 0.9888663967611336, recall : 0.9828973843058351, f1 score : 0.9858728557013119, accuracy : 0.986
# Performance for clf Model with Top 39 features is precision : 0.9911504424778761, recall : 0.9872673849167483, f1 score : 0.9892051030421982, accuracy : 0.989
# Performance for clf Model with Top 40 features is precision : 0.9879275653923542, recall : 0.9889224572004028, f1 score : 0.9884247609461501, accuracy : 0.9885
# Performance for clf Model with Top 41 features is precision : 0.983201581027668, recall : 0.983201581027668, f1 score : 0.983201581027668, accuracy : 0.983
# Performance for clf Model with Top 42 features is precision : 0.981169474727453, recall : 0.99, f1 score : 0.9855649576903932, accuracy : 0.9855
# Performance for clf Model with Top 43 features is precision : 0.9900891972249752, recall : 0.9861796643632774, f1 score : 0.9881305637982196, accuracy : 0.988
# Performance for clf Model with Top 44 features is precision : 0.9843597262952102, recall : 0.9872549019607844, f1 score : 0.9858051884483603, accuracy : 0.9855
# Performance for clf Model with Top 45 features is precision : 0.986013986013986, recall : 0.9889779559118237, f1 score : 0.9874937468734367, accuracy : 0.9875
# Performance for clf Model with Top 46 features is precision : 0.9875, recall : 0.9905956112852664, f1 score : 0.9890453834115805, accuracy : 0.9895
# Performance for clf Model with Top 47 features is precision : 0.9875, recall : 0.9808978032473734, f1 score : 0.9841878294202204, accuracy : 0.9835
# Performance for clf Model with Top 48 features is precision : 0.984015984015984, recall : 0.9879638916750251, f1 score : 0.9859859859859859, accuracy : 0.986
# Performance for clf Model with Top 49 features is precision : 0.990234375, recall : 0.9863813229571985, f1 score : 0.9883040935672515, accuracy : 0.988
# Performance for clf Model with Top 50 features is precision : 0.9896049896049897, recall : 0.9824561403508771, f1 score : 0.9860176074572761, accuracy : 0.9865

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.987654  0.982600  0.985121    0.9855
# 1                21   0.982036  0.977160  0.979592    0.9795
# 2                22   0.984048  0.987000  0.985522    0.9855
# 3                23   0.988024  0.990000  0.989011    0.9890
# 4                24   0.972000  0.980827  0.976394    0.9765
# 5                25   0.979269  0.989033  0.984127    0.9840
# 6                26   0.980473  0.980473  0.980473    0.9810
# 7                27   0.983952  0.981982  0.982966    0.9830
# 8                28   0.982125  0.980178  0.981151    0.9810
# 9                29   0.982249  0.990060  0.986139    0.9860
# 10               30   0.981188  0.985089  0.983135    0.9830
# 11               31   0.980507  0.986275  0.983382    0.9830
# 12               32   0.987000  0.979167  0.983068    0.9830
# 13               33   0.980433  0.983471  0.981949    0.9825
# 14               34   0.980159  0.988000  0.984064    0.9840
# 15               35   0.988338  0.984511  0.986421    0.9860
# 16               36   0.988154  0.980411  0.984267    0.9840
# 17               37   0.985015  0.981095  0.983051    0.9830
# 18               38   0.988866  0.982897  0.985873    0.9860
# 19               39   0.991150  0.987267  0.989205    0.9890
# 20               40   0.987928  0.988922  0.988425    0.9885
# 21               41   0.983202  0.983202  0.983202    0.9830
# 22               42   0.981169  0.990000  0.985565    0.9855
# 23               43   0.990089  0.986180  0.988131    0.9880
# 24               44   0.984360  0.987255  0.985805    0.9855
# 25               45   0.986014  0.988978  0.987494    0.9875
# 26               46   0.987500  0.990596  0.989045    0.9895
# 27               47   0.987500  0.980898  0.984188    0.9835
# 28               48   0.984016  0.987964  0.985986    0.9860
# 29               49   0.990234  0.986381  0.988304    0.9880
# 30               50   0.989605  0.982456  0.986018    0.9865

# %%
from xgboost import XGBClassifier

# %%
def train_XGBC(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    

    XGBC = XGBClassifier()
    
    XGBC.fit(X_train, y_train)

    
    y_pred = XGBC.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_XGBC(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:41:03] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 20 features is precision : 0.9831683168316832, recall : 0.9880597014925373, f1 score : 0.9856079404466501, accuracy : 0.9855
# [22:41:03] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 21 features is precision : 0.9767441860465116, recall : 0.9837067209775967, f1 score : 0.9802130898021308, accuracy : 0.9805
# [22:41:04] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 22 features is precision : 0.9860418743768694, recall : 0.97534516765286, f1 score : 0.9806643529995043, accuracy : 0.9805
# [22:41:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 23 features is precision : 0.9804526748971193, recall : 0.9814624098867147, f1 score : 0.9809572825527535, accuracy : 0.9815
# [22:41:05] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 24 features is precision : 0.9829488465396189, recall : 0.980980980980981, f1 score : 0.9819639278557114, accuracy : 0.982
# [22:41:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 25 features is precision : 0.9757820383451059, recall : 0.986734693877551, f1 score : 0.9812278031456113, accuracy : 0.9815
# [22:41:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 26 features is precision : 0.984, recall : 0.9879518072289156, f1 score : 0.9859719438877755, accuracy : 0.986
# [22:41:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 27 features is precision : 0.9783889980353635, recall : 0.9783889980353635, f1 score : 0.9783889980353635, accuracy : 0.978
# [22:41:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 28 features is precision : 0.9797101449275363, recall : 0.990234375, f1 score : 0.9849441476444877, accuracy : 0.9845
# [22:41:08] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 29 features is precision : 0.9819458375125376, recall : 0.9908906882591093, f1 score : 0.9863979848866499, accuracy : 0.9865
# [22:41:09] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 30 features is precision : 0.9856704196519959, recall : 0.9856704196519959, f1 score : 0.9856704196519959, accuracy : 0.986
# [22:41:10] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 31 features is precision : 0.9854014598540146, recall : 0.987460815047022, f1 score : 0.9864300626304802, accuracy : 0.987
# [22:41:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 32 features is precision : 0.98001998001998, recall : 0.9889112903225806, f1 score : 0.9844455594581033, accuracy : 0.9845
# [22:41:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 33 features is precision : 0.9831516352824579, recall : 0.9890329012961117, f1 score : 0.9860834990059641, accuracy : 0.986
# [22:41:12] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 34 features is precision : 0.983, recall : 0.983983983983984, f1 score : 0.9834917458729364, accuracy : 0.9835
# [22:41:13] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 35 features is precision : 0.9835589941972921, recall : 0.987378640776699, f1 score : 0.9854651162790699, accuracy : 0.985
# [22:41:14] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 36 features is precision : 0.9841112214498511, recall : 0.9850894632206759, f1 score : 0.9846000993541977, accuracy : 0.9845
# [22:41:14] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 37 features is precision : 0.9833496571988247, recall : 0.9872173058013766, f1 score : 0.985279685966634, accuracy : 0.985
# [22:41:15] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 38 features is precision : 0.9775171065493646, recall : 0.9871668311944719, f1 score : 0.9823182711198429, accuracy : 0.982
# [22:41:16] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 39 features is precision : 0.9837164750957854, recall : 0.9932301740812379, f1 score : 0.9884504331087585, accuracy : 0.988
# [22:41:17] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 40 features is precision : 0.9808274470232089, recall : 0.9948822927328557, f1 score : 0.9878048780487805, accuracy : 0.988
# [22:41:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 41 features is precision : 0.9873663751214772, recall : 0.9825918762088974, f1 score : 0.984973339796413, accuracy : 0.9845
# [22:41:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 42 features is precision : 0.9816602316602316, recall : 0.9912280701754386, f1 score : 0.9864209505334626, accuracy : 0.986
# [22:41:20] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 43 features is precision : 0.9869215291750503, recall : 0.990909090909091, f1 score : 0.9889112903225806, accuracy : 0.989
# [22:41:21] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 44 features is precision : 0.9837067209775967, recall : 0.9867211440245148, f1 score : 0.9852116267210606, accuracy : 0.9855
# [22:41:22] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 45 features is precision : 0.9879275653923542, recall : 0.9839679358717435, f1 score : 0.9859437751004017, accuracy : 0.986
# [22:41:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 46 features is precision : 0.9867482161060143, recall : 0.9877551020408163, f1 score : 0.987251402345742, accuracy : 0.9875
# [22:41:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 47 features is precision : 0.9898580121703854, recall : 0.9809045226130654, f1 score : 0.9853609288238264, accuracy : 0.9855
# [22:41:25] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 48 features is precision : 0.9848331648129424, recall : 0.9908443540183113, f1 score : 0.9878296146044625, accuracy : 0.988
# [22:41:26] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Performance for clf Model with Top 49 features is precision : 0.9881539980256664, recall : 0.9871794871794872, f1 score : 0.9876665022200296, accuracy : 0.9875
# [22:41:27] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Performance for clf Model with Top 50 features is precision : 0.9902629016553067, recall : 0.9883381924198251, f1 score : 0.9892996108949416, accuracy : 0.989
# /opt/conda/lib/python3.7/site-packages/xgboost/data.py:114: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.983168  0.988060  0.985608    0.9855
# 1                21   0.976744  0.983707  0.980213    0.9805
# 2                22   0.986042  0.975345  0.980664    0.9805
# 3                23   0.980453  0.981462  0.980957    0.9815
# 4                24   0.982949  0.980981  0.981964    0.9820
# 5                25   0.975782  0.986735  0.981228    0.9815
# 6                26   0.984000  0.987952  0.985972    0.9860
# 7                27   0.978389  0.978389  0.978389    0.9780
# 8                28   0.979710  0.990234  0.984944    0.9845
# 9                29   0.981946  0.990891  0.986398    0.9865
# 10               30   0.985670  0.985670  0.985670    0.9860
# 11               31   0.985401  0.987461  0.986430    0.9870
# 12               32   0.980020  0.988911  0.984446    0.9845
# 13               33   0.983152  0.989033  0.986083    0.9860
# 14               34   0.983000  0.983984  0.983492    0.9835
# 15               35   0.983559  0.987379  0.985465    0.9850
# 16               36   0.984111  0.985089  0.984600    0.9845
# 17               37   0.983350  0.987217  0.985280    0.9850
# 18               38   0.977517  0.987167  0.982318    0.9820
# 19               39   0.983716  0.993230  0.988450    0.9880
# 20               40   0.980827  0.994882  0.987805    0.9880
# 21               41   0.987366  0.982592  0.984973    0.9845
# 22               42   0.981660  0.991228  0.986421    0.9860
# 23               43   0.986922  0.990909  0.988911    0.9890
# 24               44   0.983707  0.986721  0.985212    0.9855
# 25               45   0.987928  0.983968  0.985944    0.9860
# 26               46   0.986748  0.987755  0.987251    0.9875
# 27               47   0.989858  0.980905  0.985361    0.9855
# 28               48   0.984833  0.990844  0.987830    0.9880
# 29               49   0.988154  0.987179  0.987667    0.9875
# 30               50   0.990263  0.988338  0.989300    0.9890

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
def train_gb_clf(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    gb_clf = GradientBoostingClassifier(n_estimators=20, learning_rate=0.1, max_features=2, max_depth=2, random_state=0)
    
    gb_clf.fit(X_train, y_train)

    
    y_pred = gb_clf.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_gb_clf(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for clf Model with Top 20 features is precision : 0.9663951120162932, recall : 0.9285714285714286, f1 score : 0.9471057884231536, accuracy : 0.947
# Performance for clf Model with Top 21 features is precision : 0.9314928425357873, recall : 0.9258130081300813, f1 score : 0.928644240570846, accuracy : 0.93
# Performance for clf Model with Top 22 features is precision : 0.9219562955254943, recall : 0.9124613800205973, f1 score : 0.9171842650103519, accuracy : 0.92
# Performance for clf Model with Top 23 features is precision : 0.9481327800829875, recall : 0.9393627954779034, f1 score : 0.9437274135260713, accuracy : 0.9455
# Performance for clf Model with Top 24 features is precision : 0.9311740890688259, recall : 0.9274193548387096, f1 score : 0.9292929292929293, accuracy : 0.93
# Performance for clf Model with Top 25 features is precision : 0.9519519519519519, recall : 0.9434523809523809, f1 score : 0.9476831091180866, accuracy : 0.9475
# Performance for clf Model with Top 26 features is precision : 0.9644779332615716, recall : 0.9005025125628141, f1 score : 0.9313929313929314, accuracy : 0.934
# Performance for clf Model with Top 27 features is precision : 0.9463753723932473, recall : 0.9482587064676616, f1 score : 0.9473161033797217, accuracy : 0.947
# Performance for clf Model with Top 28 features is precision : 0.94180407371484, recall : 0.9594861660079052, f1 score : 0.9505628976994616, accuracy : 0.9495
# Performance for clf Model with Top 29 features is precision : 0.9338159255429163, recall : 0.9204892966360856, f1 score : 0.9271047227926077, accuracy : 0.929
# Performance for clf Model with Top 30 features is precision : 0.9527310924369747, recall : 0.9255102040816326, f1 score : 0.9389233954451345, accuracy : 0.941
# Performance for clf Model with Top 31 features is precision : 0.9288537549407114, recall : 0.9073359073359073, f1 score : 0.91796875, accuracy : 0.916
# Performance for clf Model with Top 32 features is precision : 0.9173789173789174, recall : 0.9378640776699029, f1 score : 0.9275084013442151, accuracy : 0.9245
# Performance for clf Model with Top 33 features is precision : 0.922360248447205, recall : 0.9018218623481782, f1 score : 0.9119754350051178, accuracy : 0.914
# Performance for clf Model with Top 34 features is precision : 0.9303733602421796, recall : 0.9092702169625246, f1 score : 0.919700748129676, accuracy : 0.9195
# Performance for clf Model with Top 35 features is precision : 0.9322033898305084, recall : 0.9051306873184899, f1 score : 0.9184675834970532, accuracy : 0.917
# Performance for clf Model with Top 36 features is precision : 0.9275653923541247, recall : 0.9322548028311426, f1 score : 0.929904185577408, accuracy : 0.9305
# Performance for clf Model with Top 37 features is precision : 0.9395833333333333, recall : 0.9213483146067416, f1 score : 0.9303764827230532, accuracy : 0.9325
# Performance for clf Model with Top 38 features is precision : 0.9454722492697176, recall : 0.9408914728682171, f1 score : 0.9431762991743565, accuracy : 0.9415
# Performance for clf Model with Top 39 features is precision : 0.9393282773564464, recall : 0.8609731876861966, f1 score : 0.8984455958549223, accuracy : 0.902
# Performance for clf Model with Top 40 features is precision : 0.875, recall : 0.9338014042126379, f1 score : 0.903444929645803, accuracy : 0.9005
# Performance for clf Model with Top 41 features is precision : 0.9222546161321672, recall : 0.9566532258064516, f1 score : 0.9391390400791688, accuracy : 0.9385
# Performance for clf Model with Top 42 features is precision : 0.94831013916501, recall : 0.9298245614035088, f1 score : 0.9389763779527559, accuracy : 0.938
# Performance for clf Model with Top 43 features is precision : 0.9353813559322034, recall : 0.8865461847389559, f1 score : 0.9103092783505154, accuracy : 0.913
# Performance for clf Model with Top 44 features is precision : 0.9461382113821138, recall : 0.9190523198420533, f1 score : 0.9323985978968453, accuracy : 0.9325
# Performance for clf Model with Top 45 features is precision : 0.908203125, recall : 0.9281437125748503, f1 score : 0.9180651530108589, accuracy : 0.917
# Performance for clf Model with Top 46 features is precision : 0.9058713886300093, recall : 0.9427740058195926, f1 score : 0.9239543726235742, accuracy : 0.92
# Performance for clf Model with Top 47 features is precision : 0.945010183299389, recall : 0.9469387755102041, f1 score : 0.9459734964322121, accuracy : 0.947
# Performance for clf Model with Top 48 features is precision : 0.9362139917695473, recall : 0.908183632734531, f1 score : 0.9219858156028369, accuracy : 0.923
# Performance for clf Model with Top 49 features is precision : 0.9394871794871795, recall : 0.9105367793240556, f1 score : 0.9247854618879355, accuracy : 0.9255
# Performance for clf Model with Top 50 features is precision : 0.9390862944162437, recall : 0.9259259259259259, f1 score : 0.9324596774193549, accuracy : 0.933

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.966395  0.928571  0.947106    0.9470
# 1                21   0.931493  0.925813  0.928644    0.9300
# 2                22   0.921956  0.912461  0.917184    0.9200
# 3                23   0.948133  0.939363  0.943727    0.9455
# 4                24   0.931174  0.927419  0.929293    0.9300
# 5                25   0.951952  0.943452  0.947683    0.9475
# 6                26   0.964478  0.900503  0.931393    0.9340
# 7                27   0.946375  0.948259  0.947316    0.9470
# 8                28   0.941804  0.959486  0.950563    0.9495
# 9                29   0.933816  0.920489  0.927105    0.9290
# 10               30   0.952731  0.925510  0.938923    0.9410
# 11               31   0.928854  0.907336  0.917969    0.9160
# 12               32   0.917379  0.937864  0.927508    0.9245
# 13               33   0.922360  0.901822  0.911975    0.9140
# 14               34   0.930373  0.909270  0.919701    0.9195
# 15               35   0.932203  0.905131  0.918468    0.9170
# 16               36   0.927565  0.932255  0.929904    0.9305
# 17               37   0.939583  0.921348  0.930376    0.9325
# 18               38   0.945472  0.940891  0.943176    0.9415
# 19               39   0.939328  0.860973  0.898446    0.9020
# 20               40   0.875000  0.933801  0.903445    0.9005
# 21               41   0.922255  0.956653  0.939139    0.9385
# 22               42   0.948310  0.929825  0.938976    0.9380
# 23               43   0.935381  0.886546  0.910309    0.9130
# 24               44   0.946138  0.919052  0.932399    0.9325
# 25               45   0.908203  0.928144  0.918065    0.9170
# 26               46   0.905871  0.942774  0.923954    0.9200
# 27               47   0.945010  0.946939  0.945973    0.9470
# 28               48   0.936214  0.908184  0.921986    0.9230
# 29               49   0.939487  0.910537  0.924785    0.9255
# 30               50   0.939086  0.925926  0.932460    0.9330

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
def train_abc(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
    
    abc.fit(X_train, y_train)

    
    y_pred = abc.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_abc(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for clf Model with Top 20 features is precision : 0.9671641791044776, recall : 0.9759036144578314, f1 score : 0.9715142428785608, accuracy : 0.9715
# Performance for clf Model with Top 21 features is precision : 0.9713701431492843, recall : 0.9753593429158111, f1 score : 0.9733606557377049, accuracy : 0.974
# Performance for clf Model with Top 22 features is precision : 0.9707887049659202, recall : 0.9774509803921568, f1 score : 0.9741084513922813, accuracy : 0.9735
# Performance for clf Model with Top 23 features is precision : 0.975975975975976, recall : 0.9789156626506024, f1 score : 0.9774436090225564, accuracy : 0.9775
# Performance for clf Model with Top 24 features is precision : 0.9655850540806293, recall : 0.9751737835153923, f1 score : 0.9703557312252965, accuracy : 0.97
# Performance for clf Model with Top 25 features is precision : 0.9684106614017769, recall : 0.960822722820764, f1 score : 0.9646017699115044, accuracy : 0.964
# Performance for clf Model with Top 26 features is precision : 0.9618768328445748, recall : 0.9656526005888125, f1 score : 0.9637610186092068, accuracy : 0.963
# Performance for clf Model with Top 27 features is precision : 0.9666348903717826, recall : 0.9731285988483686, f1 score : 0.96987087517934, accuracy : 0.9685
# Performance for clf Model with Top 28 features is precision : 0.9707070707070707, recall : 0.9668008048289738, f1 score : 0.9687499999999999, accuracy : 0.969
# Performance for clf Model with Top 29 features is precision : 0.9621136590229312, recall : 0.965, f1 score : 0.9635546679980029, accuracy : 0.9635
# Performance for clf Model with Top 30 features is precision : 0.9742002063983488, recall : 0.9701952723535457, f1 score : 0.972193614830072, accuracy : 0.973
# Performance for clf Model with Top 31 features is precision : 0.9673802242609582, recall : 0.9713408393039918, f1 score : 0.9693564862104188, accuracy : 0.97
# Performance for clf Model with Top 32 features is precision : 0.9590163934426229, recall : 0.972972972972973, f1 score : 0.9659442724458205, accuracy : 0.967
# Performance for clf Model with Top 33 features is precision : 0.963402571711177, recall : 0.9710867397806581, f1 score : 0.9672293942403177, accuracy : 0.967
# Performance for clf Model with Top 34 features is precision : 0.9749247743229689, recall : 0.9739478957915831, f1 score : 0.9744360902255639, accuracy : 0.9745
# Performance for clf Model with Top 35 features is precision : 0.9642857142857143, recall : 0.9712230215827338, f1 score : 0.967741935483871, accuracy : 0.9685
# Performance for clf Model with Top 36 features is precision : 0.9512195121951219, recall : 0.9730538922155688, f1 score : 0.9620128268376912, accuracy : 0.9615
# Performance for clf Model with Top 37 features is precision : 0.9689621726479146, recall : 0.9746341463414634, f1 score : 0.9717898832684825, accuracy : 0.971
# Performance for clf Model with Top 38 features is precision : 0.9718592964824121, recall : 0.9593253968253969, f1 score : 0.9655516724912632, accuracy : 0.9655
# Performance for clf Model with Top 39 features is precision : 0.9680232558139535, recall : 0.9699029126213592, f1 score : 0.9689621726479146, accuracy : 0.968
# Performance for clf Model with Top 40 features is precision : 0.97002997002997, recall : 0.9652087475149106, f1 score : 0.9676133532635776, accuracy : 0.9675
# Performance for clf Model with Top 41 features is precision : 0.9672447013487476, recall : 0.9681774349083896, f1 score : 0.9677108433734941, accuracy : 0.9665
# Performance for clf Model with Top 42 features is precision : 0.9666666666666667, recall : 0.9627766599597586, f1 score : 0.9647177419354839, accuracy : 0.965
# Performance for clf Model with Top 43 features is precision : 0.9597989949748744, recall : 0.976482617586912, f1 score : 0.968068930562595, accuracy : 0.9685
# Performance for clf Model with Top 44 features is precision : 0.9571567672833495, recall : 0.9751984126984127, f1 score : 0.966093366093366, accuracy : 0.9655
# Performance for clf Model with Top 45 features is precision : 0.9764705882352941, recall : 0.9688715953307393, f1 score : 0.97265625, accuracy : 0.972
# Performance for clf Model with Top 46 features is precision : 0.9647177419354839, recall : 0.9696048632218845, f1 score : 0.967155128852956, accuracy : 0.9675
# Performance for clf Model with Top 47 features is precision : 0.9674465920651069, recall : 0.9773895169578622, f1 score : 0.9723926380368099, accuracy : 0.973
# Performance for clf Model with Top 48 features is precision : 0.957801766437684, recall : 0.9672943508424182, f1 score : 0.9625246548323472, accuracy : 0.962
# Performance for clf Model with Top 49 features is precision : 0.973026973026973, recall : 0.9681908548707754, f1 score : 0.970602889885401, accuracy : 0.9705
# Performance for clf Model with Top 50 features is precision : 0.9685349065880039, recall : 0.969488188976378, f1 score : 0.9690113133300541, accuracy : 0.9685

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.967164  0.975904  0.971514    0.9715
# 1                21   0.971370  0.975359  0.973361    0.9740
# 2                22   0.970789  0.977451  0.974108    0.9735
# 3                23   0.975976  0.978916  0.977444    0.9775
# 4                24   0.965585  0.975174  0.970356    0.9700
# 5                25   0.968411  0.960823  0.964602    0.9640
# 6                26   0.961877  0.965653  0.963761    0.9630
# 7                27   0.966635  0.973129  0.969871    0.9685
# 8                28   0.970707  0.966801  0.968750    0.9690
# 9                29   0.962114  0.965000  0.963555    0.9635
# 10               30   0.974200  0.970195  0.972194    0.9730
# 11               31   0.967380  0.971341  0.969356    0.9700
# 12               32   0.959016  0.972973  0.965944    0.9670
# 13               33   0.963403  0.971087  0.967229    0.9670
# 14               34   0.974925  0.973948  0.974436    0.9745
# 15               35   0.964286  0.971223  0.967742    0.9685
# 16               36   0.951220  0.973054  0.962013    0.9615
# 17               37   0.968962  0.974634  0.971790    0.9710
# 18               38   0.971859  0.959325  0.965552    0.9655
# 19               39   0.968023  0.969903  0.968962    0.9680
# 20               40   0.970030  0.965209  0.967613    0.9675
# 21               41   0.967245  0.968177  0.967711    0.9665
# 22               42   0.966667  0.962777  0.964718    0.9650
# 23               43   0.959799  0.976483  0.968069    0.9685
# 24               44   0.957157  0.975198  0.966093    0.9655
# 25               45   0.976471  0.968872  0.972656    0.9720
# 26               46   0.964718  0.969605  0.967155    0.9675
# 27               47   0.967447  0.977390  0.972393    0.9730
# 28               48   0.957802  0.967294  0.962525    0.9620
# 29               49   0.973027  0.968191  0.970603    0.9705
# 30               50   0.968535  0.969488  0.969011    0.9685

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
def train_rfc(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    rfc = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
    
    rfc.fit(X_train, y_train)

    
    y_pred = rfc.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_abc(data, i)
    print("Performance for clf Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for clf Model with Top 20 features is precision : 0.9582504970178927, recall : 0.9630369630369631, f1 score : 0.9606377678126558, accuracy : 0.9605
# Performance for clf Model with Top 21 features is precision : 0.9689320388349515, recall : 0.9689320388349515, f1 score : 0.9689320388349515, accuracy : 0.968
# Performance for clf Model with Top 22 features is precision : 0.965, recall : 0.9737638748738647, f1 score : 0.9693621295831241, accuracy : 0.9695
# Performance for clf Model with Top 23 features is precision : 0.9686552072800809, recall : 0.9686552072800809, f1 score : 0.9686552072800809, accuracy : 0.969
# Performance for clf Model with Top 24 features is precision : 0.9669902912621359, recall : 0.967930029154519, f1 score : 0.967459932005828, accuracy : 0.9665
# Performance for clf Model with Top 25 features is precision : 0.964035964035964, recall : 0.9718026183282981, f1 score : 0.9679037111334001, accuracy : 0.968
# Performance for clf Model with Top 26 features is precision : 0.9740777666999003, recall : 0.9692460317460317, f1 score : 0.9716558925907509, accuracy : 0.9715
# Performance for clf Model with Top 27 features is precision : 0.960285132382892, recall : 0.9721649484536082, f1 score : 0.9661885245901638, accuracy : 0.967
# Performance for clf Model with Top 28 features is precision : 0.9650485436893204, recall : 0.9773844641101278, f1 score : 0.9711773326819736, accuracy : 0.9705
# Performance for clf Model with Top 29 features is precision : 0.962172647914646, recall : 0.9763779527559056, f1 score : 0.9692232535417684, accuracy : 0.9685
# Performance for clf Model with Top 30 features is precision : 0.9744114636642784, recall : 0.9684638860630722, f1 score : 0.9714285714285714, accuracy : 0.972
# Performance for clf Model with Top 31 features is precision : 0.972027972027972, recall : 0.9759277833500501, f1 score : 0.9739739739739739, accuracy : 0.974
# Performance for clf Model with Top 32 features is precision : 0.9700103412616339, recall : 0.9660144181256437, f1 score : 0.9680082559339525, accuracy : 0.969
# Performance for clf Model with Top 33 features is precision : 0.9766970618034447, recall : 0.9688442211055276, f1 score : 0.9727547931382442, accuracy : 0.973
# Performance for clf Model with Top 34 features is precision : 0.9660523763336566, recall : 0.974559686888454, f1 score : 0.9702873843156357, accuracy : 0.9695
# Performance for clf Model with Top 35 features is precision : 0.9621513944223108, recall : 0.9689067201604814, f1 score : 0.9655172413793104, accuracy : 0.9655
# Performance for clf Model with Top 36 features is precision : 0.9696673189823874, recall : 0.9668292682926829, f1 score : 0.9682462139716659, accuracy : 0.9675
# Performance for clf Model with Top 37 features is precision : 0.9712820512820513, recall : 0.9683026584867076, f1 score : 0.9697900665642601, accuracy : 0.9705
# Performance for clf Model with Top 38 features is precision : 0.9635995955510617, recall : 0.9724489795918367, f1 score : 0.96800406297613, accuracy : 0.9685
# Performance for clf Model with Top 39 features is precision : 0.973630831643002, recall : 0.96579476861167, f1 score : 0.9696969696969696, accuracy : 0.97
# Performance for clf Model with Top 40 features is precision : 0.9666666666666667, recall : 0.9755351681957186, f1 score : 0.9710806697108066, accuracy : 0.9715
# Performance for clf Model with Top 41 features is precision : 0.9717457114026236, recall : 0.9707661290322581, f1 score : 0.9712556732223903, accuracy : 0.9715
# Performance for clf Model with Top 42 features is precision : 0.9722507708119219, recall : 0.9604060913705583, f1 score : 0.9662921348314606, accuracy : 0.967
# Performance for clf Model with Top 43 features is precision : 0.9709465791940018, recall : 0.9682242990654205, f1 score : 0.9695835283107159, accuracy : 0.9675
# Performance for clf Model with Top 44 features is precision : 0.9681908548707754, recall : 0.9672293942403177, f1 score : 0.9677098857426726, accuracy : 0.9675
# Performance for clf Model with Top 45 features is precision : 0.960668633235005, recall : 0.977, f1 score : 0.9687654933068914, accuracy : 0.9685
# Performance for clf Model with Top 46 features is precision : 0.972027972027972, recall : 0.9710578842315369, f1 score : 0.9715426859710433, accuracy : 0.9715
# Performance for clf Model with Top 47 features is precision : 0.9691675231243576, recall : 0.9632277834525026, f1 score : 0.966188524590164, accuracy : 0.967
# Performance for clf Model with Top 48 features is precision : 0.9747474747474747, recall : 0.9601990049751243, f1 score : 0.9674185463659147, accuracy : 0.9675
# Performance for clf Model with Top 49 features is precision : 0.9714285714285714, recall : 0.9733464955577492, f1 score : 0.9723865877712031, accuracy : 0.972
# Performance for clf Model with Top 50 features is precision : 0.9715964740450539, recall : 0.9735034347399412, f1 score : 0.9725490196078431, accuracy : 0.972

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall', 'f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.958250  0.963037  0.960638    0.9605
# 1                21   0.968932  0.968932  0.968932    0.9680
# 2                22   0.965000  0.973764  0.969362    0.9695
# 3                23   0.968655  0.968655  0.968655    0.9690
# 4                24   0.966990  0.967930  0.967460    0.9665
# 5                25   0.964036  0.971803  0.967904    0.9680
# 6                26   0.974078  0.969246  0.971656    0.9715
# 7                27   0.960285  0.972165  0.966189    0.9670
# 8                28   0.965049  0.977384  0.971177    0.9705
# 9                29   0.962173  0.976378  0.969223    0.9685
# 10               30   0.974411  0.968464  0.971429    0.9720
# 11               31   0.972028  0.975928  0.973974    0.9740
# 12               32   0.970010  0.966014  0.968008    0.9690
# 13               33   0.976697  0.968844  0.972755    0.9730
# 14               34   0.966052  0.974560  0.970287    0.9695
# 15               35   0.962151  0.968907  0.965517    0.9655
# 16               36   0.969667  0.966829  0.968246    0.9675
# 17               37   0.971282  0.968303  0.969790    0.9705
# 18               38   0.963600  0.972449  0.968004    0.9685
# 19               39   0.973631  0.965795  0.969697    0.9700
# 20               40   0.966667  0.975535  0.971081    0.9715
# 21               41   0.971746  0.970766  0.971256    0.9715
# 22               42   0.972251  0.960406  0.966292    0.9670
# 23               43   0.970947  0.968224  0.969584    0.9675
# 24               44   0.968191  0.967229  0.967710    0.9675
# 25               45   0.960669  0.977000  0.968765    0.9685
# 26               46   0.972028  0.971058  0.971543    0.9715
# 27               47   0.969168  0.963228  0.966189    0.9670
# 28               48   0.974747  0.960199  0.967419    0.9675
# 29               49   0.971429  0.973346  0.972387    0.9720
# 30               50   0.971596  0.973503  0.972549    0.9720
